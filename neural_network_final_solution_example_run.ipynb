# %% [markdown]
# ## Final Solution Example Run

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
from main import main

# %% [markdown]
# In this notebook we will demonstarte the use of our solution.
#
# Background Story:
# Assume we would use the video_games_sales dataset in order to predict the global sales of a given video game.
# While exploring the data before building an appropriate prediction framework, we would like to understande whether a given numeric column is actually a nominal categorical column. If this is the case, we might prefer using one-hot encoding or similar in order to represent this feature, rather than the original numeric value which might imply an unwanted order between the different values.

# %% [markdown]
# To show the viability of our solution, we chose the data such that we know the columns meaning, therefore we would know exactly what to expect. The real power of our solution is that it can help us understand non-intuitives datasets.
#
# Let us briefly introduce the data:

# %%
data_path = './datasets/converted_datasets/video_games_sales_converted_regression.csv'
data = pd.read_csv(data_path)
data
# Out:
#                                 Name  Year_of_Release     Publisher  NA_Sales  \
# 0                         Wii Sports           2006.0      Nintendo     41.36
# 1                  Super Mario Bros.           1985.0      Nintendo     29.08
# 2                     Mario Kart Wii           2008.0      Nintendo     15.68
# 3                  Wii Sports Resort           2009.0      Nintendo     15.61
# 4           Pokemon Red/Pokemon Blue           1996.0      Nintendo     11.27
# ...                              ...              ...           ...       ...
# 16714  Samurai Warriors: Sanada Maru           2016.0    Tecmo Koei      0.00
# 16715               LMA Manager 2007           2006.0   Codemasters      0.00
# 16716        Haitaka no Psychedelica           2016.0  Idea Factory      0.00
# 16717               Spirits & Spells           2003.0       Wanadoo      0.01
# 16718            Winning Post 8 2016           2016.0    Tecmo Koei      0.00
#
# ...

# %% [markdown]
# The data contains three int type columns with less than 50 unique values: Year_of_Release, Platform and Genre, we expect like them to be tested. \
#
# In addition, we would expect our model to identify that Genre and Platform are nominal columns, while Year_of_Release is ordinal.

# %%
warnings.filterwarnings("ignore")
main(data_path, 'Global_Sales', regression_task=True)
# Out:
# ['Year_of_Release' 'Platform' 'Genre'] have less than 50 unique INT values, therefore they will be checked.
# Training embedding model start.
# Epoch 1/10
# 515/515 - 2s - loss: 0.6427 - accuracy: 0.6311 - 2s/epoch - 3ms/step
# Epoch 2/10
# 515/515 - 1s - loss: 0.6290 - accuracy: 0.6443 - 863ms/epoch - 2ms/step
# Epoch 3/10
# 515/515 - 1s - loss: 0.6240 - accuracy: 0.6502 - 855ms/epoch - 2ms/step
# Epoch 4/10
# 515/515 - 1s - loss: 0.6222 - accuracy: 0.6523 - 864ms/epoch - 2ms/step
# Epoch 5/10
# 515/515 - 1s - loss: 0.6184 - accuracy: 0.6553 - 860ms/epoch - 2ms/step
# Epoch 6/10
# 515/515 - 1s - loss: 0.6157 - accuracy: 0.6582 - 859ms/epoch - 2ms/step
# Epoch 7/10
# 515/515 - 1s - loss: 0.6133 - accuracy: 0.6603 - 859ms/epoch - 2ms/step
# Epoch 8/10
# 515/515 - 1s - loss: 0.6118 - accuracy: 0.6610 - 921ms/epoch - 2ms/step
# Epoch 9/10
# 515/515 - 1s - loss: 0.6104 - accuracy: 0.6635 - 903ms/epoch - 2ms/step
# Epoch 10/10
# ...

# %% [markdown]
# Our model indeed recognizes nominal columns as we expected, additionaly, it provides the user with the spearman correlation score which can provide the certainty level.
